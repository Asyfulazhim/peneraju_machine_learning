# %% [markdown]
# # Problem 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Medals.csv')
print(df)
# Out:
#    Rank           Team  Gold  Silver  Bronze  Total  Rank_by_Total
# 0     1          China    14       6       9     29              2
# 1     2            USA    13      13      10     36              1
# 2     3          Japan    13       4       5     22              4
# 3     4            ROC     7      11       7     25              3
# 4     5      Australia     7       2      10     19              5
# 5     6  Great Britain     5       6       5     16              7
# 6     7          Korea     4       2       5     11              9
# 7     8        Germany     3       3       5     11              9
# 8     9         France     3       3       3      9             12
# 9    10          Italy     2       7       9     18              6

# %%
team = df['Team']
total = df['Total']
print(team)
print(total)
# Out:
# 0            China
# 1              USA
# 2            Japan
# 3              ROC
# 4        Australia
# 5    Great Britain
# 6            Korea
# 7          Germany
# 8           France
# 9            Italy
# Name: Team, dtype: object
# 0    29
# 1    36
# 2    22
# 3    25
# 4    19
# 5    16
# 6    11
# 7    11
# 8     9
# 9    18
# Name: Total, dtype: int64

# %%
teamlist = np.array(team)
print(teamlist)
totallist = np.array(total)
print(totallist)
# Out:
# ['China' 'USA' 'Japan' 'ROC' 'Australia' 'Great Britain' 'Korea' 'Germany'
#  'France' 'Italy']
# [29 36 22 25 19 16 11 11  9 18]

# %%
plt.plot(teamlist,totallist)

# %% [markdown]
# Figure Specifications:
#
# Set the following parameters of the plot
#
#
# xlabel : Team Name
#
# ylabel : Total Number of Medals
#
# legend : location – ‘lower right’
#
# title : Team-wise Total Medal Data
#
# Figure Name : plot2.png
#
# Styling specifications:
#
# Line Style dotted and Line-color should be red
#
# Add a circle marker with markerface color a black ('k').
#
# Line width should be 3

# %%
plt.figure(figsize=(6,4))
plt.plot(teamlist,totallist, 'o--r', mfc = 'k')
plt.xlabel('Team Name')
plt.ylabel('Total Number of Medals')
plt.title('Team-wise Total Medal Data')
plt.legend(['Team-wise Total Medal Data'],loc = 'lower right')

# %%
plt.show()

# %% [markdown]
# **Full Code Problem 1**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('Medals.csv')
#print(df)

team = df['Team']
total = df['Total']

teamlist = np.array(team)
#print(teamlist)
totallist = np.array(total)
#print(totallist)
#plt.figure(figsize=(6,4))
plt.plot(teamlist,totallist, 'o--r', mfc = 'k', linewidth = 2.5)
plt.xlabel('Team Name')
plt.ylabel('Total Number of Medals')
plt.title('Team-wise Total Medal Data')
plt.legend(['Team-wise Total Medal Data'],loc = 'lower right')
#plt.show()

plt.savefig('plot2.png')

# %%
plt.bar(teamlist, totallist)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# # Problem 2

# %%
df['Total']
# Out:
# 0    29
# 1    36
# 2    22
# 3    25
# 4    19
# 5    16
# 6    11
# 7    11
# 8     9
# 9    18
# Name: Total, dtype: int64

# %%
totallist = np.array(df['Total'])
totallist
# Out:
# array([29, 36, 22, 25, 19, 16, 11, 11,  9, 18])

# %% [markdown]
# - Read the total medals received by each team and show it using the histogram to see the most common total medals range.
# - Use the total medals range as [10,20,30,40]. Save the plot in a file named “plot6.png”

# %%
plt.hist(totallist)
# Out:
# (array([3., 0., 1., 2., 1., 1., 0., 1., 0., 1.]),
#  array([ 9. , 11.7, 14.4, 17.1, 19.8, 22.5, 25.2, 27.9, 30.6, 33.3, 36. ]),
#  <BarContainer object of 10 artists>)

# %%
range = [10,20,30,40]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('Medals.csv')

totalmedals = df['Total']
totalmedalrange = [10, 20, 30, 40]  # Ranges for the histogram


def plot_histogram(data, bins, title, x_label, y_label):
    plt.figure(figsize=(10, 6))
    plt.hist(data, bins=bins, alpha=1)
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    # plt.grid(axis='y', , alpha=0.7)
    plt.xticks(bins)
    plt.show()


if __name__ == "__main__":
    title = 'Total Medals Histogram'
    x_label = 'Total Medals Range'
    y_label = 'Count'
    
    plot_histogram(totalmedals, totalmedalrange, title, x_label, y_label)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('Medals.csv')

totalmedals = np.array(df['Total'])
totalmedalrange = [10, 20, 30, 40]  # Ranges for the histogram


def plot_histogram(data, bins, title, x_label, y_label):
    plt.figure(figsize=(10, 6))
    plt.hist(data, bins=bins, alpha=1)
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    # plt.grid(axis='y', , alpha=0.7)
    #plt.xticks(bins)
    plt.show()


if __name__ == "__main__":
    title = 'Total Medals Histogram'
    x_label = 'Total Medals Range'
    y_label = 'Count'
    
    plot_histogram(totalmedals, totalmedalrange, title, x_label, y_label)

# %%
print(np.__version__)
# Out:
# 2.0.0
