# %%
import seaborn as sns
import matplotlib.pyplot as plt

cars = sns.load_dataset('car_crashes', cache=True, data_home=r'\temp')

# Create bar plot
#plt.figure()
#sns.scatter(car_crashes['speeding'],car_crashes['alcohol'])
plt.scatter(cars['speeding'], cars['alcohol'])

# Set seaborn style
sns.set(style="whitegrid", rc={'grid.color': '.6', 'grid.linestyle': '-'})
