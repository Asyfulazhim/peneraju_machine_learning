# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('donations_state.csv')
data
# Out:
#              date              state  daily  blood_a  blood_b  blood_o  \
# 0      2006-01-01           Malaysia    525      152      139      194
# 1      2006-01-02           Malaysia    227       53       43      112
# 2      2006-01-03           Malaysia    112       29       21       56
# 3      2006-01-04           Malaysia    391       92       98      165
# 4      2006-01-05           Malaysia    582      149      198      193
# ...           ...                ...    ...      ...      ...      ...
# 94761  2024-07-09  W.P. Kuala Lumpur    586      142      163      246
# 94762  2024-07-10  W.P. Kuala Lumpur    460      117      138      171
# 94763  2024-07-11  W.P. Kuala Lumpur    408      104      113      167
# 94764  2024-07-12  W.P. Kuala Lumpur    301       72       91      117
# 94765  2024-07-13  W.P. Kuala Lumpur    988      221      261      447
#
#        blood_ab  location_centre  location_mobile  type_wholeblood  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94766 entries, 0 to 94765
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     94766 non-null  object
#  1   state                    94766 non-null  object
#  2   daily                    94766 non-null  int64
#  3   blood_a                  94766 non-null  int64
#  4   blood_b                  94766 non-null  int64
#  5   blood_o                  94766 non-null  int64
#  6   blood_ab                 94766 non-null  int64
#  7   location_centre          94766 non-null  int64
#  8   location_mobile          94766 non-null  int64
#  9   type_wholeblood          94766 non-null  int64
#  10  type_apheresis_platelet  94766 non-null  int64
#  11  type_apheresis_plasma    94766 non-null  int64
#  12  type_other               94766 non-null  int64
#  13  social_civilian          94766 non-null  int64
# ...

# %%
data.describe()
# Out:
#               daily       blood_a       blood_b       blood_o      blood_ab  \
# count  94766.000000  94766.000000  94766.000000  94766.000000  94766.000000
# mean     180.749826     44.891881     49.204377     75.417323     11.231686
# std      374.231379     93.535117    101.635114    156.977854     23.272487
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       19.000000      4.000000      5.000000      8.000000      1.000000
# 50%       58.000000     14.000000     16.000000     24.000000      3.000000
# 75%      137.000000     34.000000     38.000000     57.000000      9.000000
# max     5543.000000   1368.000000   1599.000000   2184.000000    392.000000
#
#        location_centre  location_mobile  type_wholeblood  \
# count     94766.000000     94766.000000     94766.000000
# mean         95.989574        84.760252       177.094084
# std         205.746736       235.788117       368.383635
# ...
